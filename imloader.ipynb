# %%
import zipfile
import matplotlib.pyplot as plt
import numpy as np

# %%
_ARCH_PATH = "/Users/iudalov/code/TinyDiffusion/data/imagenet-object-localization-challenge.zip"

# %%
zipFile = zipfile.ZipFile(_ARCH_PATH)
image_names = list(filter(lambda x: not x.endswith(".xml"), zipFile.namelist()))

for image_name in image_names[:100]:
    zipfile.ZipFile(_ARCH_PATH).extract(image_name)

# %%
for image_name in list(filter(lambda x: x.endswith(".xml"), zipFile.namelist()))[:100]:
    print(image_name)
    zipfile.ZipFile(_ARCH_PATH).extract(image_name)
# Out:
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10040.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10048.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10074.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_1009.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10108.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10251.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10293.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10323.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10342.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10361.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10365.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10427.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10449.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_105.xml
# ILSVRC/Annotations/CLS-LOC/train/n01440764/n01440764_10514.xml
# ...
